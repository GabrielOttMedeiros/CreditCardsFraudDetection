# %%
dtc
# Out:
#     max_depth  cut_off  accuracy    recall  Performance
# 0           3     0.05  0.975195  0.741445     0.842405
# 1           3     0.10  0.994887  0.463403     0.632294
# 2           3     0.15  0.994887  0.463403     0.632294
# 3           3     0.20  0.994887  0.463403     0.632294
# 4           3     0.25  0.994887  0.463403     0.632294
# ..        ...      ...       ...       ...          ...
# 83         10     0.35  0.993969  0.667300     0.798517
# 84         10     0.40  0.994174  0.660646     0.793799
# 85         10     0.45  0.994174  0.660646     0.793799
# 86         10     0.50  0.994254  0.654943     0.789693
# 87         10     0.55  0.995519  0.575570     0.729419
#
# [88 rows x 5 columns]

# %%
import pandas as pd

lr = pd.read_csv('LR_results.csv')
ada_dtc = pd.read_csv('ADA_DTC.csv')
dtc = pd.read_csv('DTC_results.csv')
nn = pd.read_csv('NN_results.csv')
rf = pd.read_csv('RF_results.csv')
svc = pd.read_csv('SVC_results.csv')
gbc = pd.read_csv('GBC_results.csv')

lr = lr[['accuracy','recall','Performance','cut_off']]
ada_dtc = ada_dtc[['accuracy','recall','Performance','cut_off']]
nn = nn[['accuracy','recall','Performance']]
svc = svc[['accuracy','recall','Performance','cut_off']]
dtc = dtc[['accuracy','recall','Performance','cut_off']]
rf = rf[['accuracy','recall','Performance','cut_off']]
gbc = gbc[['accuracy','recall','Performance','cut_off']]

lr['Model'] = 'LogisticRegression'
ada_dtc['Model'] = 'AdaBoostDecisionTrees'
nn['Model'] = 'NeuralNetworks'
svc['Model'] = 'SupportVectorMachine'
dtc['Model'] = 'DecisionTrees'
rf['Model'] = 'RandomForest'
gbc['Model'] = 'GradientBoosting'


results = pd.concat([lr,ada_dtc,nn, svc, dtc, rf])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-eee9f0c1f0fa> in <module>
#      13 nn = rf[['accuracy','recall','Performance']]
#      14 svc = ada_dtc[['accuracy','recall','Performance','cut_off']]
# ---> 15 dtc = nn[['accuracy','recall','Performance','cut_off']]
#      16 rf = svc[['accuracy','recall','Performance','cut_off']]
#      17 gbc = gbc[['accuracy','recall','Performance','cut_off']]
#
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2910             if is_iterator(key):
#    2911                 key = list(key)
# -> 2912             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2913
#    2914         # take() does not accept boolean indexers
#
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
#    1256
#
# ~/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1302             if raise_missing:
#    1303                 not_found = list(set(key) - set(ax))
# -> 1304                 raise KeyError(f"{not_found} not in index")
#    1305
#    1306             # we skip the warning on Categorical
#
# KeyError: "['cut_off'] not in index"

# %%
results.to_csv('FinalResultsConcat.csv', index = False)
